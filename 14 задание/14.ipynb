# %% [markdown]
# ![{75A4EDC7-9CEA-4CBC-873D-F08FF85EA205}.png](attachment:{75A4EDC7-9CEA-4CBC-873D-F08FF85EA205}.png)

# %%
for x in '0123456789ABCDEF':
    temp = int('8'+x+'834', 16) + int('44'+x + '27', 16)
    if temp % 23 == 0:
        print(temp//23)
# Out:
# 36701

# %% [markdown]
# ![{5E0FD193-8469-4E71-A9C0-5DBD67240C3F}.png](attachment:{5E0FD193-8469-4E71-A9C0-5DBD67240C3F}.png)

# %%
s = '0123456789ABCDEF'

# %%
for x in s[:-1]:
    temp = int('123'+x +'5', 15) + int('1' + x + '233', 15)
    if temp % 14 == 0:
        print(temp//14)
# Out:
# 8767
# 10462

# %% [markdown]
# ![{58E7C7A4-1368-41C8-8C9B-A23C249DFCEC}.png](attachment:{58E7C7A4-1368-41C8-8C9B-A23C249DFCEC}.png)

# %%
for x in '0123456789abcdefghi':
    temp = int('78')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(int(I, 19))
#
# NameError: name 'I' is not defined

# %% [markdown]
# ![{25D4F11D-C8BB-4AB5-A9EE-16C0A1028414}.png](attachment:{25D4F11D-C8BB-4AB5-A9EE-16C0A1028414}.png)

# %%
t = 2 * 729 ** 2014 + 2 * 81**2018 + 2*27**2020 - 2 * 9*2022 - 2024
count = 0
while t!=0:
    if t%27 > 9:
        count += 1
    t //= 27

print(count)
# Out:
# 2018

# %% [markdown]
# ![{E8A2F245-740A-4A3D-8505-F5599A9CFD3E}.png](attachment:{E8A2F245-740A-4A3D-8505-F5599A9CFD3E}.png)

# %%
for p in range(15,100):
    answer = 8 + 13 * p**1 + 7 * p**2 + p**3 * 6 + p**4 * 9 + p**5 *11 + p**6 * 10 + 8 + p*9 + p**2 * 10 + p**3 * 5 + p**4 * 3 + p**5 *4 + 14 * p**6
    if answer % (p-1) == 0:
        print(p)
# Out:
# 40

# %% [markdown]
# ![{B07EF8D3-411A-4972-876F-F5F464BEBF26}.png](attachment:{B07EF8D3-411A-4972-876F-F5F464BEBF26}.png)

# %% [markdown]
# ![{083D0E21-9C5B-48B2-AB6A-C7FD5AEAD272}.png](attachment:{083D0E21-9C5B-48B2-AB6A-C7FD5AEAD272}.png)

# %% [markdown]
# ![{79FCFBE3-E4AE-4CCD-852E-5C437F8AB43E}.png](attachment:{79FCFBE3-E4AE-4CCD-852E-5C437F8AB43E}.png)

# %%
for x in range(100):
    for y in range(100):
        temp = 9 + 40 * 1 + 40**2 * y + 40**3 * 2 + 40**4 * 9 + 40**5 * 6 + 40**6 * x + 40**7 * 7 + 40**8 * 5


        temp_2 = x + y * 40
       
        if temp % 39 == 0 and int(temp_2**0.5) == temp_2**0.5:
            print(x + y*40)
# Out:
# 0
# 1521
# 1521
# 1521

# %%
print(9**0.5 == 3)
# Out:
# True

# %% [markdown]
# ![{3BC29E37-C7ED-4B6F-9F29-1D1CF6C1C117}.png](attachment:{3BC29E37-C7ED-4B6F-9F29-1D1CF6C1C117}.png)

# %%
minim = 10e10
for p in range(1,30):
    for x in range(0,p):
        for y in range(1,p):
            for z in range(1,p):
                for w in range(1,p):
                    a = x + p * 7 + p**3 * y
                    b = z + 9 * p + y * p ** 2 + w * p**3
                    c = y + x*p**1 + y *p**2 + x * p ** 3 + z *p**4
                    if a + b == c and len([x,y,z,w]) == len(set([x,y,z,w])):
                        print(w + z * p + y * p **2 + x * p**3, p,"|", x,y,z,w)
# Out:
# 115918 19 | 16 17 1 18
# 134839 20 | 16 17 1 19
# 155714 21 | 16 17 1 20
# 178639 22 | 16 17 1 21
# 203710 23 | 16 17 1 22
# 231023 24 | 16 17 1 23
# 260674 25 | 16 17 1 24
# 292759 26 | 16 17 1 25
# 327374 27 | 16 17 1 26
# 364615 28 | 16 17 1 27
# 404578 29 | 16 17 1 28

# %% [markdown]
# ![{1D0E1E50-0124-46DE-AFBC-812512FB7BBE}.png](attachment:{1D0E1E50-0124-46DE-AFBC-812512FB7BBE}.png)

# %%
maxim = 0
result = 0
for x in range(1, int(10e5)):
    t = 7**400 + 7 ** 300 - x
    count = 0
    while t > 0:
        if t % 7 == 0:
            count += 1
        t //=7
    result = max(maxim, count)
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 6
#       4 t = 7**400 + 7 ** 300 - x
#       5 count = 0
# ----> 6 while t > 0:
#       7     if t % 7 == 0:
#       8         count += 1
#
# KeyboardInterrupt:

# %%
10e2
# Out:
# 1000.0

# %% [markdown]
# ![{EBA38101-053A-4476-84B1-258C256A7095}.png](attachment:{EBA38101-053A-4476-84B1-258C256A7095}.png)

# %%
for x in range(1,2030+1):
    temp = 6**260 + 6**160 + 6**60 - x


    while temp > 0:
        count += (temp%6 == 0)
        temp//=6
    if count == 202:
        print(x)
        break
    count = 0
# Out:
# 216

# %% [markdown]
# ![{0F5C1F36-5C5C-48CD-AA1A-7E2759B43484}.png](attachment:{0F5C1F36-5C5C-48CD-AA1A-7E2759B43484}.png)

# %% [markdown]
# ![{D62F4120-D5F4-49D6-855C-0599FAC866F7}.png](attachment:{D62F4120-D5F4-49D6-855C-0599FAC866F7}.png)

# %%
for x in range(10):
    osn = int(f"1{x}324")
    num1 = 3 + 2 * osn
    num2 = 2 +  x * 22 + 22**2 * 4 + 22**3 * 3 + 22**4 * 1
    if (num2-num1)%50 == 31:
        print((num2-num1)//50)
# Out:
# 4870
